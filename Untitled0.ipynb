# %% [markdown]
# <a href="https://colab.research.google.com/github/nx020215/tangerine_price_prediction/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

# %matplotlib
# %matplotlib inline
import os
os.chdir('/content')

# !python Chap_12_Reinforced_Learning_Training.py
# Out:
# Using matplotlib backend: agg
# 2023-05-30 04:18:19.020000: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-30 04:18:20.020118: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-30 04:18:21.586679: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:22.040089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:22.040386: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:22.048840: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:22.049089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:22.049289: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:24.623010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:24.623307: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:24.623505: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:18:24.623653: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-30 04:18:24.623693: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13664 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 트레이닝을 시작합니다.
# /content/Chap_12_Reinforced_Learning_Training.py:168: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.gameOver = np.empty(self.maxMemory, dtype = np.bool)
# 2023-05-30 04:18:27.331445: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x42432e00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-30 04:18:27.331502: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2023-05-30 04:18:27.814397: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8700
# 2023-05-30 04:18:28.248547: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f42d0bf8310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0530 04:18:28.516679 139926740580160 polymorphic_function.py:156] 5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f42d0bf8310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f42d0bf8310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0530 04:18:28.590399 139926740580160 polymorphic_function.py:156] 6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f42d0bf8310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 반복(Epoch): 0, 에러(err): 0.0214, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 1, 에러(err): 0.0509, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# /content/model.ckpt-1 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 2, 에러(err): 0.1283, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 3, 에러(err): 0.1403, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 4, 에러(err): 0.2242, 승리횟수(Win count): 1, 승리비율(Win ratio): 20.0000
# 반복(Epoch): 5, 에러(err): 0.2553, 승리횟수(Win count): 1, 승리비율(Win ratio): 16.6667
# 반복(Epoch): 6, 에러(err): 0.3254, 승리횟수(Win count): 1, 승리비율(Win ratio): 14.2857
# 반복(Epoch): 7, 에러(err): 0.3101, 승리횟수(Win count): 1, 승리비율(Win ratio): 12.5000
# 반복(Epoch): 8, 에러(err): 0.3921, 승리횟수(Win count): 1, 승리비율(Win ratio): 11.1111
# 반복(Epoch): 9, 에러(err): 0.3305, 승리횟수(Win count): 2, 승리비율(Win ratio): 20.0000
# 반복(Epoch): 10, 에러(err): 0.3360, 승리횟수(Win count): 2, 승리비율(Win ratio): 18.1818
# 반복(Epoch): 11, 에러(err): 0.3076, 승리횟수(Win count): 2, 승리비율(Win ratio): 16.6667
# 반복(Epoch): 12, 에러(err): 0.3143, 승리횟수(Win count): 2, 승리비율(Win ratio): 15.3846
# 반복(Epoch): 13, 에러(err): 0.3211, 승리횟수(Win count): 2, 승리비율(Win ratio): 14.2857
# 반복(Epoch): 14, 에러(err): 0.3467, 승리횟수(Win count): 2, 승리비율(Win ratio): 13.3333
# 반복(Epoch): 15, 에러(err): 0.3051, 승리횟수(Win count): 3, 승리비율(Win ratio): 18.7500
# 반복(Epoch): 16, 에러(err): 0.3367, 승리횟수(Win count): 3, 승리비율(Win ratio): 17.6471
# 반복(Epoch): 17, 에러(err): 0.3610, 승리횟수(Win count): 3, 승리비율(Win ratio): 16.6667
# 반복(Epoch): 18, 에러(err): 0.3390, 승리횟수(Win count): 3, 승리비율(Win ratio): 15.7895
# 반복(Epoch): 19, 에러(err): 0.2563, 승리횟수(Win count): 3, 승리비율(Win ratio): 15.0000
# 반복(Epoch): 20, 에러(err): 0.3986, 승리횟수(Win count): 3, 승리비율(Win ratio): 14.2857
# 반복(Epoch): 21, 에러(err): 0.3349, 승리횟수(Win count): 3, 승리비율(Win ratio): 13.6364
# 반복(Epoch): 22, 에러(err): 0.2921, 승리횟수(Win count): 3, 승리비율(Win ratio): 13.0435
# 반복(Epoch): 23, 에러(err): 0.2187, 승리횟수(Win count): 3, 승리비율(Win ratio): 12.5000
# 반복(Epoch): 24, 에러(err): 0.2039, 승리횟수(Win count): 3, 승리비율(Win ratio): 12.0000
# 반복(Epoch): 25, 에러(err): 0.2255, 승리횟수(Win count): 3, 승리비율(Win ratio): 11.5385
# 반복(Epoch): 26, 에러(err): 0.3202, 승리횟수(Win count): 4, 승리비율(Win ratio): 14.8148
# 반복(Epoch): 27, 에러(err): 0.2089, 승리횟수(Win count): 4, 승리비율(Win ratio): 14.2857
# 반복(Epoch): 28, 에러(err): 0.2120, 승리횟수(Win count): 5, 승리비율(Win ratio): 17.2414
# 반복(Epoch): 29, 에러(err): 0.3126, 승리횟수(Win count): 5, 승리비율(Win ratio): 16.6667
# 반복(Epoch): 30, 에러(err): 0.2284, 승리횟수(Win count): 5, 승리비율(Win ratio): 16.1290
# 반복(Epoch): 31, 에러(err): 0.2354, 승리횟수(Win count): 5, 승리비율(Win ratio): 15.6250
# 반복(Epoch): 32, 에러(err): 0.2486, 승리횟수(Win count): 5, 승리비율(Win ratio): 15.1515
# 반복(Epoch): 33, 에러(err): 0.2462, 승리횟수(Win count): 6, 승리비율(Win ratio): 17.6471
# 반복(Epoch): 34, 에러(err): 0.2424, 승리횟수(Win count): 7, 승리비율(Win ratio): 20.0000
# 반복(Epoch): 35, 에러(err): 0.2211, 승리횟수(Win count): 8, 승리비율(Win ratio): 22.2222
# 반복(Epoch): 36, 에러(err): 0.2818, 승리횟수(Win count): 8, 승리비율(Win ratio): 21.6216
# 반복(Epoch): 37, 에러(err): 0.2719, 승리횟수(Win count): 8, 승리비율(Win ratio): 21.0526
# 반복(Epoch): 38, 에러(err): 0.2170, 승리횟수(Win count): 8, 승리비율(Win ratio): 20.5128
# 반복(Epoch): 39, 에러(err): 0.1848, 승리횟수(Win count): 8, 승리비율(Win ratio): 20.0000
# 반복(Epoch): 40, 에러(err): 0.2887, 승리횟수(Win count): 8, 승리비율(Win ratio): 19.5122
# 반복(Epoch): 41, 에러(err): 0.1995, 승리횟수(Win count): 9, 승리비율(Win ratio): 21.4286
# 반복(Epoch): 42, 에러(err): 0.2417, 승리횟수(Win count): 9, 승리비율(Win ratio): 20.9302
# 반복(Epoch): 43, 에러(err): 0.2691, 승리횟수(Win count): 9, 승리비율(Win ratio): 20.4545
# 반복(Epoch): 44, 에러(err): 0.2631, 승리횟수(Win count): 9, 승리비율(Win ratio): 20.0000
# 반복(Epoch): 45, 에러(err): 0.2596, 승리횟수(Win count): 9, 승리비율(Win ratio): 19.5652
# 반복(Epoch): 46, 에러(err): 0.2407, 승리횟수(Win count): 9, 승리비율(Win ratio): 19.1489
# 반복(Epoch): 47, 에러(err): 0.2158, 승리횟수(Win count): 9, 승리비율(Win ratio): 18.7500
# 반복(Epoch): 48, 에러(err): 0.2032, 승리횟수(Win count): 10, 승리비율(Win ratio): 20.4082
# 반복(Epoch): 49, 에러(err): 0.2534, 승리횟수(Win count): 11, 승리비율(Win ratio): 22.0000
# 반복(Epoch): 50, 에러(err): 0.2338, 승리횟수(Win count): 11, 승리비율(Win ratio): 21.5686
# 반복(Epoch): 51, 에러(err): 0.2334, 승리횟수(Win count): 11, 승리비율(Win ratio): 21.1538
# 반복(Epoch): 52, 에러(err): 0.2865, 승리횟수(Win count): 12, 승리비율(Win ratio): 22.6415
# 반복(Epoch): 53, 에러(err): 0.2044, 승리횟수(Win count): 12, 승리비율(Win ratio): 22.2222
# 반복(Epoch): 54, 에러(err): 0.1951, 승리횟수(Win count): 12, 승리비율(Win ratio): 21.8182
# 반복(Epoch): 55, 에러(err): 0.3045, 승리횟수(Win count): 13, 승리비율(Win ratio): 23.2143
# 반복(Epoch): 56, 에러(err): 0.2085, 승리횟수(Win count): 14, 승리비율(Win ratio): 24.5614
# 반복(Epoch): 57, 에러(err): 0.1841, 승리횟수(Win count): 15, 승리비율(Win ratio): 25.8621
# 반복(Epoch): 58, 에러(err): 0.1958, 승리횟수(Win count): 15, 승리비율(Win ratio): 25.4237
# 반복(Epoch): 59, 에러(err): 0.2422, 승리횟수(Win count): 15, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 60, 에러(err): 0.1901, 승리횟수(Win count): 15, 승리비율(Win ratio): 24.5902
# 반복(Epoch): 61, 에러(err): 0.2612, 승리횟수(Win count): 15, 승리비율(Win ratio): 24.1935
# 반복(Epoch): 62, 에러(err): 0.1991, 승리횟수(Win count): 16, 승리비율(Win ratio): 25.3968
# 반복(Epoch): 63, 에러(err): 0.1911, 승리횟수(Win count): 16, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 64, 에러(err): 0.2259, 승리횟수(Win count): 16, 승리비율(Win ratio): 24.6154
# 반복(Epoch): 65, 에러(err): 0.2427, 승리횟수(Win count): 16, 승리비율(Win ratio): 24.2424
# 반복(Epoch): 66, 에러(err): 0.2136, 승리횟수(Win count): 16, 승리비율(Win ratio): 23.8806
# 반복(Epoch): 67, 에러(err): 0.1839, 승리횟수(Win count): 16, 승리비율(Win ratio): 23.5294
# 반복(Epoch): 68, 에러(err): 0.1945, 승리횟수(Win count): 17, 승리비율(Win ratio): 24.6377
# 반복(Epoch): 69, 에러(err): 0.2688, 승리횟수(Win count): 17, 승리비율(Win ratio): 24.2857
# 반복(Epoch): 70, 에러(err): 0.2612, 승리횟수(Win count): 17, 승리비율(Win ratio): 23.9437
# 반복(Epoch): 71, 에러(err): 0.1938, 승리횟수(Win count): 18, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 72, 에러(err): 0.1763, 승리횟수(Win count): 18, 승리비율(Win ratio): 24.6575
# 반복(Epoch): 73, 에러(err): 0.1736, 승리횟수(Win count): 18, 승리비율(Win ratio): 24.3243
# 반복(Epoch): 74, 에러(err): 0.1966, 승리횟수(Win count): 18, 승리비율(Win ratio): 24.0000
# 반복(Epoch): 75, 에러(err): 0.1947, 승리횟수(Win count): 18, 승리비율(Win ratio): 23.6842
# 반복(Epoch): 76, 에러(err): 0.2118, 승리횟수(Win count): 18, 승리비율(Win ratio): 23.3766
# 반복(Epoch): 77, 에러(err): 0.1709, 승리횟수(Win count): 18, 승리비율(Win ratio): 23.0769
# 반복(Epoch): 78, 에러(err): 0.2260, 승리횟수(Win count): 19, 승리비율(Win ratio): 24.0506
# 반복(Epoch): 79, 에러(err): 0.2103, 승리횟수(Win count): 19, 승리비율(Win ratio): 23.7500
# 반복(Epoch): 80, 에러(err): 0.1863, 승리횟수(Win count): 19, 승리비율(Win ratio): 23.4568
# 반복(Epoch): 81, 에러(err): 0.1450, 승리횟수(Win count): 19, 승리비율(Win ratio): 23.1707
# 반복(Epoch): 82, 에러(err): 0.2255, 승리횟수(Win count): 19, 승리비율(Win ratio): 22.8916
# 반복(Epoch): 83, 에러(err): 0.2239, 승리횟수(Win count): 19, 승리비율(Win ratio): 22.6190
# 반복(Epoch): 84, 에러(err): 0.2522, 승리횟수(Win count): 19, 승리비율(Win ratio): 22.3529
# 반복(Epoch): 85, 에러(err): 0.1792, 승리횟수(Win count): 19, 승리비율(Win ratio): 22.0930
# 반복(Epoch): 86, 에러(err): 0.1545, 승리횟수(Win count): 20, 승리비율(Win ratio): 22.9885
# 반복(Epoch): 87, 에러(err): 0.1864, 승리횟수(Win count): 20, 승리비율(Win ratio): 22.7273
# 반복(Epoch): 88, 에러(err): 0.1713, 승리횟수(Win count): 20, 승리비율(Win ratio): 22.4719
# 반복(Epoch): 89, 에러(err): 0.1638, 승리횟수(Win count): 20, 승리비율(Win ratio): 22.2222
# 반복(Epoch): 90, 에러(err): 0.2070, 승리횟수(Win count): 20, 승리비율(Win ratio): 21.9780
# 반복(Epoch): 91, 에러(err): 0.1601, 승리횟수(Win count): 21, 승리비율(Win ratio): 22.8261
# 반복(Epoch): 92, 에러(err): 0.1639, 승리횟수(Win count): 21, 승리비율(Win ratio): 22.5806
# 반복(Epoch): 93, 에러(err): 0.1555, 승리횟수(Win count): 21, 승리비율(Win ratio): 22.3404
# 반복(Epoch): 94, 에러(err): 0.1892, 승리횟수(Win count): 21, 승리비율(Win ratio): 22.1053
# 반복(Epoch): 95, 에러(err): 0.2037, 승리횟수(Win count): 21, 승리비율(Win ratio): 21.8750
# 반복(Epoch): 96, 에러(err): 0.1770, 승리횟수(Win count): 22, 승리비율(Win ratio): 22.6804
# 반복(Epoch): 97, 에러(err): 0.2121, 승리횟수(Win count): 22, 승리비율(Win ratio): 22.4490
# 반복(Epoch): 98, 에러(err): 0.1931, 승리횟수(Win count): 22, 승리비율(Win ratio): 22.2222
# 반복(Epoch): 99, 에러(err): 0.3435, 승리횟수(Win count): 22, 승리비율(Win ratio): 22.0000
# 반복(Epoch): 100, 에러(err): 0.2083, 승리횟수(Win count): 23, 승리비율(Win ratio): 22.7723
# 반복(Epoch): 101, 에러(err): 0.1786, 승리횟수(Win count): 24, 승리비율(Win ratio): 23.5294
# /content/model.ckpt-101 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 102, 에러(err): 0.1494, 승리횟수(Win count): 25, 승리비율(Win ratio): 24.2718
# 반복(Epoch): 103, 에러(err): 0.1423, 승리횟수(Win count): 25, 승리비율(Win ratio): 24.0385
# 반복(Epoch): 104, 에러(err): 0.1321, 승리횟수(Win count): 26, 승리비율(Win ratio): 24.7619
# 반복(Epoch): 105, 에러(err): 0.1695, 승리횟수(Win count): 26, 승리비율(Win ratio): 24.5283
# 반복(Epoch): 106, 에러(err): 0.2740, 승리횟수(Win count): 26, 승리비율(Win ratio): 24.2991
# 반복(Epoch): 107, 에러(err): 0.1966, 승리횟수(Win count): 27, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 108, 에러(err): 0.2952, 승리횟수(Win count): 28, 승리비율(Win ratio): 25.6881
# 반복(Epoch): 109, 에러(err): 0.1376, 승리횟수(Win count): 28, 승리비율(Win ratio): 25.4545
# 반복(Epoch): 110, 에러(err): 0.1714, 승리횟수(Win count): 28, 승리비율(Win ratio): 25.2252
# 반복(Epoch): 111, 에러(err): 0.1668, 승리횟수(Win count): 29, 승리비율(Win ratio): 25.8929
# 반복(Epoch): 112, 에러(err): 0.2832, 승리횟수(Win count): 29, 승리비율(Win ratio): 25.6637
# 반복(Epoch): 113, 에러(err): 0.2301, 승리횟수(Win count): 29, 승리비율(Win ratio): 25.4386
# 반복(Epoch): 114, 에러(err): 0.1796, 승리횟수(Win count): 29, 승리비율(Win ratio): 25.2174
# 반복(Epoch): 115, 에러(err): 0.1781, 승리횟수(Win count): 30, 승리비율(Win ratio): 25.8621
# 반복(Epoch): 116, 에러(err): 0.1293, 승리횟수(Win count): 31, 승리비율(Win ratio): 26.4957
# 반복(Epoch): 117, 에러(err): 0.1254, 승리횟수(Win count): 32, 승리비율(Win ratio): 27.1186
# 반복(Epoch): 118, 에러(err): 0.2145, 승리횟수(Win count): 33, 승리비율(Win ratio): 27.7311
# 반복(Epoch): 119, 에러(err): 0.1523, 승리횟수(Win count): 34, 승리비율(Win ratio): 28.3333
# 반복(Epoch): 120, 에러(err): 0.1597, 승리횟수(Win count): 34, 승리비율(Win ratio): 28.0992
# 반복(Epoch): 121, 에러(err): 0.1713, 승리횟수(Win count): 34, 승리비율(Win ratio): 27.8689
# 반복(Epoch): 122, 에러(err): 0.2819, 승리횟수(Win count): 34, 승리비율(Win ratio): 27.6423
# 반복(Epoch): 123, 에러(err): 0.2922, 승리횟수(Win count): 34, 승리비율(Win ratio): 27.4194
# 반복(Epoch): 124, 에러(err): 0.3878, 승리횟수(Win count): 34, 승리비율(Win ratio): 27.2000
# 반복(Epoch): 125, 에러(err): 0.2224, 승리횟수(Win count): 34, 승리비율(Win ratio): 26.9841
# 반복(Epoch): 126, 에러(err): 0.3877, 승리횟수(Win count): 34, 승리비율(Win ratio): 26.7717
# 반복(Epoch): 127, 에러(err): 0.2410, 승리횟수(Win count): 35, 승리비율(Win ratio): 27.3438
# 반복(Epoch): 128, 에러(err): 0.2165, 승리횟수(Win count): 35, 승리비율(Win ratio): 27.1318
# 반복(Epoch): 129, 에러(err): 0.2756, 승리횟수(Win count): 35, 승리비율(Win ratio): 26.9231
# 반복(Epoch): 130, 에러(err): 0.2214, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.4809
# 반복(Epoch): 131, 에러(err): 0.2919, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 132, 에러(err): 0.2444, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.0677
# 반복(Epoch): 133, 에러(err): 0.1193, 승리횟수(Win count): 36, 승리비율(Win ratio): 26.8657
# 반복(Epoch): 134, 에러(err): 0.2120, 승리횟수(Win count): 36, 승리비율(Win ratio): 26.6667
# 반복(Epoch): 135, 에러(err): 0.2203, 승리횟수(Win count): 36, 승리비율(Win ratio): 26.4706
# 반복(Epoch): 136, 에러(err): 0.2223, 승리횟수(Win count): 36, 승리비율(Win ratio): 26.2774
# 반복(Epoch): 137, 에러(err): 0.2339, 승리횟수(Win count): 36, 승리비율(Win ratio): 26.0870
# 반복(Epoch): 138, 에러(err): 0.1985, 승리횟수(Win count): 36, 승리비율(Win ratio): 25.8993
# 반복(Epoch): 139, 에러(err): 0.2275, 승리횟수(Win count): 37, 승리비율(Win ratio): 26.4286
# 반복(Epoch): 140, 에러(err): 0.3488, 승리횟수(Win count): 37, 승리비율(Win ratio): 26.2411
# 반복(Epoch): 141, 에러(err): 0.1407, 승리횟수(Win count): 37, 승리비율(Win ratio): 26.0563
# 반복(Epoch): 142, 에러(err): 0.1937, 승리횟수(Win count): 37, 승리비율(Win ratio): 25.8741
# 반복(Epoch): 143, 에러(err): 0.4996, 승리횟수(Win count): 37, 승리비율(Win ratio): 25.6944
# 반복(Epoch): 144, 에러(err): 0.1937, 승리횟수(Win count): 37, 승리비율(Win ratio): 25.5172
# 반복(Epoch): 145, 에러(err): 0.1414, 승리횟수(Win count): 37, 승리비율(Win ratio): 25.3425
# 반복(Epoch): 146, 에러(err): 0.2734, 승리횟수(Win count): 37, 승리비율(Win ratio): 25.1701
# 반복(Epoch): 147, 에러(err): 0.2265, 승리횟수(Win count): 38, 승리비율(Win ratio): 25.6757
# 반복(Epoch): 148, 에러(err): 0.2445, 승리횟수(Win count): 39, 승리비율(Win ratio): 26.1745
# 반복(Epoch): 149, 에러(err): 0.2325, 승리횟수(Win count): 39, 승리비율(Win ratio): 26.0000
# 반복(Epoch): 150, 에러(err): 0.1809, 승리횟수(Win count): 40, 승리비율(Win ratio): 26.4901
# 반복(Epoch): 151, 에러(err): 0.1898, 승리횟수(Win count): 41, 승리비율(Win ratio): 26.9737
# 반복(Epoch): 152, 에러(err): 0.2107, 승리횟수(Win count): 41, 승리비율(Win ratio): 26.7974
# 반복(Epoch): 153, 에러(err): 0.1796, 승리횟수(Win count): 41, 승리비율(Win ratio): 26.6234
# 반복(Epoch): 154, 에러(err): 0.2559, 승리횟수(Win count): 41, 승리비율(Win ratio): 26.4516
# 반복(Epoch): 155, 에러(err): 0.1789, 승리횟수(Win count): 42, 승리비율(Win ratio): 26.9231
# 반복(Epoch): 156, 에러(err): 0.2086, 승리횟수(Win count): 42, 승리비율(Win ratio): 26.7516
# 반복(Epoch): 157, 에러(err): 0.2086, 승리횟수(Win count): 43, 승리비율(Win ratio): 27.2152
# 반복(Epoch): 158, 에러(err): 0.2894, 승리횟수(Win count): 44, 승리비율(Win ratio): 27.6730
# 반복(Epoch): 159, 에러(err): 0.3878, 승리횟수(Win count): 44, 승리비율(Win ratio): 27.5000
# 반복(Epoch): 160, 에러(err): 0.2539, 승리횟수(Win count): 45, 승리비율(Win ratio): 27.9503
# 반복(Epoch): 161, 에러(err): 0.2854, 승리횟수(Win count): 45, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 162, 에러(err): 0.1865, 승리횟수(Win count): 45, 승리비율(Win ratio): 27.6074
# 반복(Epoch): 163, 에러(err): 0.1996, 승리횟수(Win count): 45, 승리비율(Win ratio): 27.4390
# 반복(Epoch): 164, 에러(err): 0.2207, 승리횟수(Win count): 45, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 165, 에러(err): 0.1507, 승리횟수(Win count): 46, 승리비율(Win ratio): 27.7108
# 반복(Epoch): 166, 에러(err): 0.2164, 승리횟수(Win count): 47, 승리비율(Win ratio): 28.1437
# 반복(Epoch): 167, 에러(err): 0.3021, 승리횟수(Win count): 47, 승리비율(Win ratio): 27.9762
# 반복(Epoch): 168, 에러(err): 0.1850, 승리횟수(Win count): 48, 승리비율(Win ratio): 28.4024
# 반복(Epoch): 169, 에러(err): 0.1304, 승리횟수(Win count): 48, 승리비율(Win ratio): 28.2353
# 반복(Epoch): 170, 에러(err): 0.1495, 승리횟수(Win count): 48, 승리비율(Win ratio): 28.0702
# 반복(Epoch): 171, 에러(err): 0.1372, 승리횟수(Win count): 48, 승리비율(Win ratio): 27.9070
# 반복(Epoch): 172, 에러(err): 0.2472, 승리횟수(Win count): 48, 승리비율(Win ratio): 27.7457
# 반복(Epoch): 173, 에러(err): 0.1482, 승리횟수(Win count): 48, 승리비율(Win ratio): 27.5862
# 반복(Epoch): 174, 에러(err): 0.1635, 승리횟수(Win count): 49, 승리비율(Win ratio): 28.0000
# 반복(Epoch): 175, 에러(err): 0.2817, 승리횟수(Win count): 50, 승리비율(Win ratio): 28.4091
# 반복(Epoch): 176, 에러(err): 0.2307, 승리횟수(Win count): 51, 승리비율(Win ratio): 28.8136
# 반복(Epoch): 177, 에러(err): 0.1243, 승리횟수(Win count): 51, 승리비율(Win ratio): 28.6517
# 반복(Epoch): 178, 에러(err): 0.2076, 승리횟수(Win count): 52, 승리비율(Win ratio): 29.0503
# 반복(Epoch): 179, 에러(err): 0.2049, 승리횟수(Win count): 52, 승리비율(Win ratio): 28.8889
# 반복(Epoch): 180, 에러(err): 0.2168, 승리횟수(Win count): 53, 승리비율(Win ratio): 29.2818
# 반복(Epoch): 181, 에러(err): 0.1897, 승리횟수(Win count): 53, 승리비율(Win ratio): 29.1209
# 반복(Epoch): 182, 에러(err): 0.2411, 승리횟수(Win count): 53, 승리비율(Win ratio): 28.9617
# 반복(Epoch): 183, 에러(err): 0.1442, 승리횟수(Win count): 53, 승리비율(Win ratio): 28.8043
# 반복(Epoch): 184, 에러(err): 0.1233, 승리횟수(Win count): 54, 승리비율(Win ratio): 29.1892
# 반복(Epoch): 185, 에러(err): 0.2773, 승리횟수(Win count): 55, 승리비율(Win ratio): 29.5699
# 반복(Epoch): 186, 에러(err): 0.1846, 승리횟수(Win count): 55, 승리비율(Win ratio): 29.4118
# 반복(Epoch): 187, 에러(err): 0.4019, 승리횟수(Win count): 56, 승리비율(Win ratio): 29.7872
# 반복(Epoch): 188, 에러(err): 0.3079, 승리횟수(Win count): 56, 승리비율(Win ratio): 29.6296
# 반복(Epoch): 189, 에러(err): 0.3170, 승리횟수(Win count): 57, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 190, 에러(err): 0.2321, 승리횟수(Win count): 58, 승리비율(Win ratio): 30.3665
# 반복(Epoch): 191, 에러(err): 0.1249, 승리횟수(Win count): 58, 승리비율(Win ratio): 30.2083
# 반복(Epoch): 192, 에러(err): 0.2070, 승리횟수(Win count): 59, 승리비율(Win ratio): 30.5699
# 반복(Epoch): 193, 에러(err): 0.3235, 승리횟수(Win count): 59, 승리비율(Win ratio): 30.4124
# 반복(Epoch): 194, 에러(err): 0.1572, 승리횟수(Win count): 59, 승리비율(Win ratio): 30.2564
# 반복(Epoch): 195, 에러(err): 0.2761, 승리횟수(Win count): 59, 승리비율(Win ratio): 30.1020
# 반복(Epoch): 196, 에러(err): 0.3641, 승리횟수(Win count): 60, 승리비율(Win ratio): 30.4569
# 반복(Epoch): 197, 에러(err): 0.2401, 승리횟수(Win count): 60, 승리비율(Win ratio): 30.3030
# 반복(Epoch): 198, 에러(err): 0.1342, 승리횟수(Win count): 60, 승리비율(Win ratio): 30.1508
# 반복(Epoch): 199, 에러(err): 0.2250, 승리횟수(Win count): 61, 승리비율(Win ratio): 30.5000
# 반복(Epoch): 200, 에러(err): 0.1984, 승리횟수(Win count): 62, 승리비율(Win ratio): 30.8458
# 반복(Epoch): 201, 에러(err): 0.1580, 승리횟수(Win count): 63, 승리비율(Win ratio): 31.1881
# /content/model.ckpt-201 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 202, 에러(err): 0.2031, 승리횟수(Win count): 64, 승리비율(Win ratio): 31.5271
# 반복(Epoch): 203, 에러(err): 0.2316, 승리횟수(Win count): 64, 승리비율(Win ratio): 31.3725
# 반복(Epoch): 204, 에러(err): 0.1409, 승리횟수(Win count): 64, 승리비율(Win ratio): 31.2195
# 반복(Epoch): 205, 에러(err): 0.1682, 승리횟수(Win count): 65, 승리비율(Win ratio): 31.5534
# 반복(Epoch): 206, 에러(err): 0.1481, 승리횟수(Win count): 66, 승리비율(Win ratio): 31.8841
# 반복(Epoch): 207, 에러(err): 0.2158, 승리횟수(Win count): 66, 승리비율(Win ratio): 31.7308
# 반복(Epoch): 208, 에러(err): 0.1869, 승리횟수(Win count): 66, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 209, 에러(err): 0.1313, 승리횟수(Win count): 66, 승리비율(Win ratio): 31.4286
# 반복(Epoch): 210, 에러(err): 0.1440, 승리횟수(Win count): 66, 승리비율(Win ratio): 31.2796
# 반복(Epoch): 211, 에러(err): 0.2125, 승리횟수(Win count): 67, 승리비율(Win ratio): 31.6038
# 반복(Epoch): 212, 에러(err): 0.1957, 승리횟수(Win count): 67, 승리비율(Win ratio): 31.4554
# 반복(Epoch): 213, 에러(err): 0.1549, 승리횟수(Win count): 68, 승리비율(Win ratio): 31.7757
# 반복(Epoch): 214, 에러(err): 0.1636, 승리횟수(Win count): 68, 승리비율(Win ratio): 31.6279
# 반복(Epoch): 215, 에러(err): 0.3120, 승리횟수(Win count): 69, 승리비율(Win ratio): 31.9444
# 반복(Epoch): 216, 에러(err): 0.2329, 승리횟수(Win count): 69, 승리비율(Win ratio): 31.7972
# 반복(Epoch): 217, 에러(err): 0.1406, 승리횟수(Win count): 69, 승리비율(Win ratio): 31.6514
# 반복(Epoch): 218, 에러(err): 0.2861, 승리횟수(Win count): 69, 승리비율(Win ratio): 31.5068
# 반복(Epoch): 219, 에러(err): 0.1762, 승리횟수(Win count): 69, 승리비율(Win ratio): 31.3636
# 반복(Epoch): 220, 에러(err): 0.1643, 승리횟수(Win count): 70, 승리비율(Win ratio): 31.6742
# 반복(Epoch): 221, 에러(err): 0.1897, 승리횟수(Win count): 71, 승리비율(Win ratio): 31.9820
# 반복(Epoch): 222, 에러(err): 0.1533, 승리횟수(Win count): 72, 승리비율(Win ratio): 32.2870
# 반복(Epoch): 223, 에러(err): 0.1309, 승리횟수(Win count): 73, 승리비율(Win ratio): 32.5893
# 반복(Epoch): 224, 에러(err): 0.1865, 승리횟수(Win count): 74, 승리비율(Win ratio): 32.8889
# 반복(Epoch): 225, 에러(err): 0.2074, 승리횟수(Win count): 75, 승리비율(Win ratio): 33.1858
# 반복(Epoch): 226, 에러(err): 0.0798, 승리횟수(Win count): 76, 승리비율(Win ratio): 33.4802
# 반복(Epoch): 227, 에러(err): 0.1088, 승리횟수(Win count): 76, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 228, 에러(err): 0.1463, 승리횟수(Win count): 77, 승리비율(Win ratio): 33.6245
# 반복(Epoch): 229, 에러(err): 0.1469, 승리횟수(Win count): 78, 승리비율(Win ratio): 33.9130
# 반복(Epoch): 230, 에러(err): 0.1402, 승리횟수(Win count): 79, 승리비율(Win ratio): 34.1991
# 반복(Epoch): 231, 에러(err): 0.3323, 승리횟수(Win count): 79, 승리비율(Win ratio): 34.0517
# 반복(Epoch): 232, 에러(err): 0.1582, 승리횟수(Win count): 79, 승리비율(Win ratio): 33.9056
# 반복(Epoch): 233, 에러(err): 0.1008, 승리횟수(Win count): 79, 승리비율(Win ratio): 33.7607
# 반복(Epoch): 234, 에러(err): 0.2510, 승리횟수(Win count): 80, 승리비율(Win ratio): 34.0426
# 반복(Epoch): 235, 에러(err): 0.1154, 승리횟수(Win count): 81, 승리비율(Win ratio): 34.3220
# 반복(Epoch): 236, 에러(err): 0.1613, 승리횟수(Win count): 82, 승리비율(Win ratio): 34.5992
# 반복(Epoch): 237, 에러(err): 0.1451, 승리횟수(Win count): 83, 승리비율(Win ratio): 34.8739
# 반복(Epoch): 238, 에러(err): 0.4684, 승리횟수(Win count): 83, 승리비율(Win ratio): 34.7280
# 반복(Epoch): 239, 에러(err): 0.2000, 승리횟수(Win count): 84, 승리비율(Win ratio): 35.0000
# 반복(Epoch): 240, 에러(err): 0.1246, 승리횟수(Win count): 85, 승리비율(Win ratio): 35.2697
# 반복(Epoch): 241, 에러(err): 0.2377, 승리횟수(Win count): 86, 승리비율(Win ratio): 35.5372
# 반복(Epoch): 242, 에러(err): 0.2294, 승리횟수(Win count): 87, 승리비율(Win ratio): 35.8025
# 반복(Epoch): 243, 에러(err): 0.0897, 승리횟수(Win count): 87, 승리비율(Win ratio): 35.6557
# 반복(Epoch): 244, 에러(err): 0.1103, 승리횟수(Win count): 88, 승리비율(Win ratio): 35.9184
# 반복(Epoch): 245, 에러(err): 0.1617, 승리횟수(Win count): 88, 승리비율(Win ratio): 35.7724
# 반복(Epoch): 246, 에러(err): 0.1771, 승리횟수(Win count): 88, 승리비율(Win ratio): 35.6275
# 반복(Epoch): 247, 에러(err): 0.1282, 승리횟수(Win count): 89, 승리비율(Win ratio): 35.8871
# 반복(Epoch): 248, 에러(err): 0.2071, 승리횟수(Win count): 90, 승리비율(Win ratio): 36.1446
# 반복(Epoch): 249, 에러(err): 0.1988, 승리횟수(Win count): 91, 승리비율(Win ratio): 36.4000
# 반복(Epoch): 250, 에러(err): 0.1717, 승리횟수(Win count): 91, 승리비율(Win ratio): 36.2550
# 반복(Epoch): 251, 에러(err): 0.0993, 승리횟수(Win count): 92, 승리비율(Win ratio): 36.5079
# 반복(Epoch): 252, 에러(err): 0.3113, 승리횟수(Win count): 93, 승리비율(Win ratio): 36.7589
# 반복(Epoch): 253, 에러(err): 0.1521, 승리횟수(Win count): 94, 승리비율(Win ratio): 37.0079
# 반복(Epoch): 254, 에러(err): 0.1890, 승리횟수(Win count): 94, 승리비율(Win ratio): 36.8627
# 반복(Epoch): 255, 에러(err): 0.1014, 승리횟수(Win count): 94, 승리비율(Win ratio): 36.7188
# 반복(Epoch): 256, 에러(err): 0.1476, 승리횟수(Win count): 95, 승리비율(Win ratio): 36.9650
# 반복(Epoch): 257, 에러(err): 0.5620, 승리횟수(Win count): 96, 승리비율(Win ratio): 37.2093
# 반복(Epoch): 258, 에러(err): 0.2742, 승리횟수(Win count): 96, 승리비율(Win ratio): 37.0656
# 반복(Epoch): 259, 에러(err): 0.2605, 승리횟수(Win count): 97, 승리비율(Win ratio): 37.3077
# 반복(Epoch): 260, 에러(err): 0.1661, 승리횟수(Win count): 98, 승리비율(Win ratio): 37.5479
# 반복(Epoch): 261, 에러(err): 0.0937, 승리횟수(Win count): 98, 승리비율(Win ratio): 37.4046
# 반복(Epoch): 262, 에러(err): 0.3974, 승리횟수(Win count): 98, 승리비율(Win ratio): 37.2624
# 반복(Epoch): 263, 에러(err): 0.1335, 승리횟수(Win count): 98, 승리비율(Win ratio): 37.1212
# 반복(Epoch): 264, 에러(err): 0.1400, 승리횟수(Win count): 98, 승리비율(Win ratio): 36.9811
# 반복(Epoch): 265, 에러(err): 0.2697, 승리횟수(Win count): 99, 승리비율(Win ratio): 37.2180
# 반복(Epoch): 266, 에러(err): 0.3271, 승리횟수(Win count): 100, 승리비율(Win ratio): 37.4532
# 반복(Epoch): 267, 에러(err): 0.3351, 승리횟수(Win count): 101, 승리비율(Win ratio): 37.6866
# 반복(Epoch): 268, 에러(err): 0.3858, 승리횟수(Win count): 102, 승리비율(Win ratio): 37.9182
# 반복(Epoch): 269, 에러(err): 0.1692, 승리횟수(Win count): 103, 승리비율(Win ratio): 38.1481
# 반복(Epoch): 270, 에러(err): 0.0630, 승리횟수(Win count): 104, 승리비율(Win ratio): 38.3764
# 반복(Epoch): 271, 에러(err): 0.2968, 승리횟수(Win count): 104, 승리비율(Win ratio): 38.2353
# 반복(Epoch): 272, 에러(err): 0.1922, 승리횟수(Win count): 104, 승리비율(Win ratio): 38.0952
# 반복(Epoch): 273, 에러(err): 0.2230, 승리횟수(Win count): 105, 승리비율(Win ratio): 38.3212
# 반복(Epoch): 274, 에러(err): 0.1558, 승리횟수(Win count): 106, 승리비율(Win ratio): 38.5455
# 반복(Epoch): 275, 에러(err): 0.0778, 승리횟수(Win count): 107, 승리비율(Win ratio): 38.7681
# 반복(Epoch): 276, 에러(err): 0.1895, 승리횟수(Win count): 108, 승리비율(Win ratio): 38.9892
# 반복(Epoch): 277, 에러(err): 0.1280, 승리횟수(Win count): 109, 승리비율(Win ratio): 39.2086
# 반복(Epoch): 278, 에러(err): 0.1062, 승리횟수(Win count): 109, 승리비율(Win ratio): 39.0681
# 반복(Epoch): 279, 에러(err): 0.0959, 승리횟수(Win count): 110, 승리비율(Win ratio): 39.2857
# 반복(Epoch): 280, 에러(err): 0.0773, 승리횟수(Win count): 111, 승리비율(Win ratio): 39.5018
# 반복(Epoch): 281, 에러(err): 0.1022, 승리횟수(Win count): 112, 승리비율(Win ratio): 39.7163
# 반복(Epoch): 282, 에러(err): 0.1074, 승리횟수(Win count): 113, 승리비율(Win ratio): 39.9293
# 반복(Epoch): 283, 에러(err): 0.0946, 승리횟수(Win count): 113, 승리비율(Win ratio): 39.7887
# 반복(Epoch): 284, 에러(err): 0.0950, 승리횟수(Win count): 113, 승리비율(Win ratio): 39.6491
# 반복(Epoch): 285, 에러(err): 0.1256, 승리횟수(Win count): 113, 승리비율(Win ratio): 39.5105
# 반복(Epoch): 286, 에러(err): 0.0941, 승리횟수(Win count): 114, 승리비율(Win ratio): 39.7213
# 반복(Epoch): 287, 에러(err): 0.2054, 승리횟수(Win count): 115, 승리비율(Win ratio): 39.9306
# 반복(Epoch): 288, 에러(err): 0.0966, 승리횟수(Win count): 116, 승리비율(Win ratio): 40.1384
# 반복(Epoch): 289, 에러(err): 0.1241, 승리횟수(Win count): 117, 승리비율(Win ratio): 40.3448
# 반복(Epoch): 290, 에러(err): 0.0964, 승리횟수(Win count): 117, 승리비율(Win ratio): 40.2062
# 반복(Epoch): 291, 에러(err): 0.0758, 승리횟수(Win count): 117, 승리비율(Win ratio): 40.0685
# 반복(Epoch): 292, 에러(err): 0.1423, 승리횟수(Win count): 118, 승리비율(Win ratio): 40.2730
# 반복(Epoch): 293, 에러(err): 0.0507, 승리횟수(Win count): 119, 승리비율(Win ratio): 40.4762
# 반복(Epoch): 294, 에러(err): 0.1166, 승리횟수(Win count): 120, 승리비율(Win ratio): 40.6780
# 반복(Epoch): 295, 에러(err): 0.1579, 승리횟수(Win count): 121, 승리비율(Win ratio): 40.8784
# 반복(Epoch): 296, 에러(err): 0.0983, 승리횟수(Win count): 122, 승리비율(Win ratio): 41.0774
# 반복(Epoch): 297, 에러(err): 0.1248, 승리횟수(Win count): 123, 승리비율(Win ratio): 41.2752
# 반복(Epoch): 298, 에러(err): 0.0684, 승리횟수(Win count): 124, 승리비율(Win ratio): 41.4716
# 반복(Epoch): 299, 에러(err): 0.0949, 승리횟수(Win count): 124, 승리비율(Win ratio): 41.3333
# 반복(Epoch): 300, 에러(err): 0.0346, 승리횟수(Win count): 125, 승리비율(Win ratio): 41.5282
# 반복(Epoch): 301, 에러(err): 0.0233, 승리횟수(Win count): 125, 승리비율(Win ratio): 41.3907
# /content/model.ckpt-301 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 302, 에러(err): 0.0723, 승리횟수(Win count): 126, 승리비율(Win ratio): 41.5842
# 반복(Epoch): 303, 에러(err): 0.0882, 승리횟수(Win count): 127, 승리비율(Win ratio): 41.7763
# 반복(Epoch): 304, 에러(err): 0.0709, 승리횟수(Win count): 128, 승리비율(Win ratio): 41.9672
# 반복(Epoch): 305, 에러(err): 0.0326, 승리횟수(Win count): 129, 승리비율(Win ratio): 42.1569
# 반복(Epoch): 306, 에러(err): 0.0604, 승리횟수(Win count): 130, 승리비율(Win ratio): 42.3453
# 반복(Epoch): 307, 에러(err): 0.0745, 승리횟수(Win count): 131, 승리비율(Win ratio): 42.5325
# 반복(Epoch): 308, 에러(err): 0.0747, 승리횟수(Win count): 132, 승리비율(Win ratio): 42.7184
# 반복(Epoch): 309, 에러(err): 0.1152, 승리횟수(Win count): 133, 승리비율(Win ratio): 42.9032
# 반복(Epoch): 310, 에러(err): 0.0685, 승리횟수(Win count): 134, 승리비율(Win ratio): 43.0868
# 반복(Epoch): 311, 에러(err): 0.1107, 승리횟수(Win count): 135, 승리비율(Win ratio): 43.2692
# 반복(Epoch): 312, 에러(err): 0.0364, 승리횟수(Win count): 136, 승리비율(Win ratio): 43.4505
# 반복(Epoch): 313, 에러(err): 0.0313, 승리횟수(Win count): 137, 승리비율(Win ratio): 43.6306
# 반복(Epoch): 314, 에러(err): 0.0388, 승리횟수(Win count): 138, 승리비율(Win ratio): 43.8095
# 반복(Epoch): 315, 에러(err): 0.0257, 승리횟수(Win count): 139, 승리비율(Win ratio): 43.9873
# 반복(Epoch): 316, 에러(err): 0.0502, 승리횟수(Win count): 140, 승리비율(Win ratio): 44.1640
# 반복(Epoch): 317, 에러(err): 0.0675, 승리횟수(Win count): 141, 승리비율(Win ratio): 44.3396
# 반복(Epoch): 318, 에러(err): 0.0593, 승리횟수(Win count): 142, 승리비율(Win ratio): 44.5141
# 반복(Epoch): 319, 에러(err): 0.0261, 승리횟수(Win count): 142, 승리비율(Win ratio): 44.3750
# 반복(Epoch): 320, 에러(err): 0.0354, 승리횟수(Win count): 142, 승리비율(Win ratio): 44.2368
# 반복(Epoch): 321, 에러(err): 0.0352, 승리횟수(Win count): 143, 승리비율(Win ratio): 44.4099
# 반복(Epoch): 322, 에러(err): 0.0939, 승리횟수(Win count): 144, 승리비율(Win ratio): 44.5820
# 반복(Epoch): 323, 에러(err): 0.0293, 승리횟수(Win count): 145, 승리비율(Win ratio): 44.7531
# 반복(Epoch): 324, 에러(err): 0.0382, 승리횟수(Win count): 146, 승리비율(Win ratio): 44.9231
# 반복(Epoch): 325, 에러(err): 0.0242, 승리횟수(Win count): 146, 승리비율(Win ratio): 44.7853
# 반복(Epoch): 326, 에러(err): 0.0377, 승리횟수(Win count): 147, 승리비율(Win ratio): 44.9541
# 반복(Epoch): 327, 에러(err): 0.0301, 승리횟수(Win count): 148, 승리비율(Win ratio): 45.1220
# 반복(Epoch): 328, 에러(err): 0.0222, 승리횟수(Win count): 148, 승리비율(Win ratio): 44.9848
# 반복(Epoch): 329, 에러(err): 0.0251, 승리횟수(Win count): 149, 승리비율(Win ratio): 45.1515
# 반복(Epoch): 330, 에러(err): 0.0617, 승리횟수(Win count): 149, 승리비율(Win ratio): 45.0151
# 반복(Epoch): 331, 에러(err): 0.0178, 승리횟수(Win count): 149, 승리비율(Win ratio): 44.8795
# 반복(Epoch): 332, 에러(err): 0.0377, 승리횟수(Win count): 150, 승리비율(Win ratio): 45.0450
# 반복(Epoch): 333, 에러(err): 0.0578, 승리횟수(Win count): 151, 승리비율(Win ratio): 45.2096
# 반복(Epoch): 334, 에러(err): 0.0563, 승리횟수(Win count): 152, 승리비율(Win ratio): 45.3731
# 반복(Epoch): 335, 에러(err): 0.0273, 승리횟수(Win count): 152, 승리비율(Win ratio): 45.2381
# 반복(Epoch): 336, 에러(err): 0.0366, 승리횟수(Win count): 152, 승리비율(Win ratio): 45.1039
# 반복(Epoch): 337, 에러(err): 0.0274, 승리횟수(Win count): 153, 승리비율(Win ratio): 45.2663
# 반복(Epoch): 338, 에러(err): 0.0342, 승리횟수(Win count): 153, 승리비율(Win ratio): 45.1327
# 반복(Epoch): 339, 에러(err): 0.0535, 승리횟수(Win count): 154, 승리비율(Win ratio): 45.2941
# 반복(Epoch): 340, 에러(err): 0.0189, 승리횟수(Win count): 155, 승리비율(Win ratio): 45.4545
# 반복(Epoch): 341, 에러(err): 0.0307, 승리횟수(Win count): 156, 승리비율(Win ratio): 45.6140
# 반복(Epoch): 342, 에러(err): 0.0236, 승리횟수(Win count): 157, 승리비율(Win ratio): 45.7726
# 반복(Epoch): 343, 에러(err): 0.0341, 승리횟수(Win count): 157, 승리비율(Win ratio): 45.6395
# 반복(Epoch): 344, 에러(err): 0.0455, 승리횟수(Win count): 158, 승리비율(Win ratio): 45.7971
# 반복(Epoch): 345, 에러(err): 0.0727, 승리횟수(Win count): 159, 승리비율(Win ratio): 45.9538
# 반복(Epoch): 346, 에러(err): 0.0201, 승리횟수(Win count): 160, 승리비율(Win ratio): 46.1095
# 반복(Epoch): 347, 에러(err): 0.0200, 승리횟수(Win count): 161, 승리비율(Win ratio): 46.2644
# 반복(Epoch): 348, 에러(err): 0.0406, 승리횟수(Win count): 162, 승리비율(Win ratio): 46.4183
# 반복(Epoch): 349, 에러(err): 0.0282, 승리횟수(Win count): 163, 승리비율(Win ratio): 46.5714
# 반복(Epoch): 350, 에러(err): 0.0238, 승리횟수(Win count): 164, 승리비율(Win ratio): 46.7236
# 반복(Epoch): 351, 에러(err): 0.0258, 승리횟수(Win count): 165, 승리비율(Win ratio): 46.8750
# 반복(Epoch): 352, 에러(err): 0.0455, 승리횟수(Win count): 166, 승리비율(Win ratio): 47.0255
# 반복(Epoch): 353, 에러(err): 0.0309, 승리횟수(Win count): 167, 승리비율(Win ratio): 47.1751
# 반복(Epoch): 354, 에러(err): 0.0961, 승리횟수(Win count): 168, 승리비율(Win ratio): 47.3239
# 반복(Epoch): 355, 에러(err): 0.0426, 승리횟수(Win count): 169, 승리비율(Win ratio): 47.4719
# 반복(Epoch): 356, 에러(err): 0.0258, 승리횟수(Win count): 170, 승리비율(Win ratio): 47.6190
# 반복(Epoch): 357, 에러(err): 0.0335, 승리횟수(Win count): 171, 승리비율(Win ratio): 47.7654
# 반복(Epoch): 358, 에러(err): 0.0311, 승리횟수(Win count): 172, 승리비율(Win ratio): 47.9109
# 반복(Epoch): 359, 에러(err): 0.0322, 승리횟수(Win count): 172, 승리비율(Win ratio): 47.7778
# 반복(Epoch): 360, 에러(err): 0.2972, 승리횟수(Win count): 172, 승리비율(Win ratio): 47.6454
# 반복(Epoch): 361, 에러(err): 0.0570, 승리횟수(Win count): 173, 승리비율(Win ratio): 47.7901
# 반복(Epoch): 362, 에러(err): 0.0281, 승리횟수(Win count): 173, 승리비율(Win ratio): 47.6584
# 반복(Epoch): 363, 에러(err): 0.1521, 승리횟수(Win count): 174, 승리비율(Win ratio): 47.8022
# 반복(Epoch): 364, 에러(err): 0.0667, 승리횟수(Win count): 174, 승리비율(Win ratio): 47.6712
# 반복(Epoch): 365, 에러(err): 0.0877, 승리횟수(Win count): 174, 승리비율(Win ratio): 47.5410
# 반복(Epoch): 366, 에러(err): 0.0412, 승리횟수(Win count): 175, 승리비율(Win ratio): 47.6839
# 반복(Epoch): 367, 에러(err): 0.3652, 승리횟수(Win count): 176, 승리비율(Win ratio): 47.8261
# 반복(Epoch): 368, 에러(err): 0.0706, 승리횟수(Win count): 176, 승리비율(Win ratio): 47.6965
# 반복(Epoch): 369, 에러(err): 0.0888, 승리횟수(Win count): 176, 승리비율(Win ratio): 47.5676
# 반복(Epoch): 370, 에러(err): 0.0370, 승리횟수(Win count): 177, 승리비율(Win ratio): 47.7089
# 반복(Epoch): 371, 에러(err): 0.1551, 승리횟수(Win count): 178, 승리비율(Win ratio): 47.8495
# 반복(Epoch): 372, 에러(err): 0.0792, 승리횟수(Win count): 179, 승리비율(Win ratio): 47.9893
# 반복(Epoch): 373, 에러(err): 0.0397, 승리횟수(Win count): 180, 승리비율(Win ratio): 48.1283
# 반복(Epoch): 374, 에러(err): 0.0354, 승리횟수(Win count): 181, 승리비율(Win ratio): 48.2667
# 반복(Epoch): 375, 에러(err): 0.0858, 승리횟수(Win count): 181, 승리비율(Win ratio): 48.1383
# 반복(Epoch): 376, 에러(err): 0.1661, 승리횟수(Win count): 182, 승리비율(Win ratio): 48.2759
# 반복(Epoch): 377, 에러(err): 0.0546, 승리횟수(Win count): 183, 승리비율(Win ratio): 48.4127
# 반복(Epoch): 378, 에러(err): 0.0772, 승리횟수(Win count): 183, 승리비율(Win ratio): 48.2850
# 반복(Epoch): 379, 에러(err): 0.0754, 승리횟수(Win count): 184, 승리비율(Win ratio): 48.4211
# 반복(Epoch): 380, 에러(err): 0.0379, 승리횟수(Win count): 184, 승리비율(Win ratio): 48.2940
# 반복(Epoch): 381, 에러(err): 0.0328, 승리횟수(Win count): 184, 승리비율(Win ratio): 48.1675
# 반복(Epoch): 382, 에러(err): 0.0539, 승리횟수(Win count): 185, 승리비율(Win ratio): 48.3029
# 반복(Epoch): 383, 에러(err): 0.0460, 승리횟수(Win count): 186, 승리비율(Win ratio): 48.4375
# 반복(Epoch): 384, 에러(err): 0.0201, 승리횟수(Win count): 187, 승리비율(Win ratio): 48.5714
# 반복(Epoch): 385, 에러(err): 0.0435, 승리횟수(Win count): 188, 승리비율(Win ratio): 48.7047
# 반복(Epoch): 386, 에러(err): 0.0264, 승리횟수(Win count): 189, 승리비율(Win ratio): 48.8372
# 반복(Epoch): 387, 에러(err): 0.0301, 승리횟수(Win count): 190, 승리비율(Win ratio): 48.9691
# 반복(Epoch): 388, 에러(err): 0.0568, 승리횟수(Win count): 191, 승리비율(Win ratio): 49.1003
# 반복(Epoch): 389, 에러(err): 0.0391, 승리횟수(Win count): 192, 승리비율(Win ratio): 49.2308
# 반복(Epoch): 390, 에러(err): 0.0435, 승리횟수(Win count): 193, 승리비율(Win ratio): 49.3606
# 반복(Epoch): 391, 에러(err): 0.0289, 승리횟수(Win count): 194, 승리비율(Win ratio): 49.4898
# 반복(Epoch): 392, 에러(err): 0.0201, 승리횟수(Win count): 195, 승리비율(Win ratio): 49.6183
# 반복(Epoch): 393, 에러(err): 0.0193, 승리횟수(Win count): 196, 승리비율(Win ratio): 49.7462
# 반복(Epoch): 394, 에러(err): 0.0137, 승리횟수(Win count): 197, 승리비율(Win ratio): 49.8734
# 반복(Epoch): 395, 에러(err): 0.0201, 승리횟수(Win count): 198, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 396, 에러(err): 0.0344, 승리횟수(Win count): 199, 승리비율(Win ratio): 50.1259
# 반복(Epoch): 397, 에러(err): 0.0145, 승리횟수(Win count): 199, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 398, 에러(err): 0.0179, 승리횟수(Win count): 200, 승리비율(Win ratio): 50.1253
# 반복(Epoch): 399, 에러(err): 0.0198, 승리횟수(Win count): 200, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 400, 에러(err): 0.0242, 승리횟수(Win count): 200, 승리비율(Win ratio): 49.8753
# 반복(Epoch): 401, 에러(err): 0.0102, 승리횟수(Win count): 200, 승리비율(Win ratio): 49.7512
# /content/model.ckpt-401 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 402, 에러(err): 0.0139, 승리횟수(Win count): 200, 승리비율(Win ratio): 49.6278
# 반복(Epoch): 403, 에러(err): 0.0113, 승리횟수(Win count): 201, 승리비율(Win ratio): 49.7525
# 반복(Epoch): 404, 에러(err): 0.0194, 승리횟수(Win count): 202, 승리비율(Win ratio): 49.8765
# 반복(Epoch): 405, 에러(err): 0.0149, 승리횟수(Win count): 203, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 406, 에러(err): 0.0255, 승리횟수(Win count): 204, 승리비율(Win ratio): 50.1229
# 반복(Epoch): 407, 에러(err): 0.0169, 승리횟수(Win count): 205, 승리비율(Win ratio): 50.2451
# 반복(Epoch): 408, 에러(err): 0.0096, 승리횟수(Win count): 206, 승리비율(Win ratio): 50.3667
# 반복(Epoch): 409, 에러(err): 0.0166, 승리횟수(Win count): 207, 승리비율(Win ratio): 50.4878
# 반복(Epoch): 410, 에러(err): 0.0264, 승리횟수(Win count): 208, 승리비율(Win ratio): 50.6083
# 반복(Epoch): 411, 에러(err): 0.0140, 승리횟수(Win count): 209, 승리비율(Win ratio): 50.7282
# 반복(Epoch): 412, 에러(err): 0.0212, 승리횟수(Win count): 210, 승리비율(Win ratio): 50.8475
# 반복(Epoch): 413, 에러(err): 0.0109, 승리횟수(Win count): 211, 승리비율(Win ratio): 50.9662
# 반복(Epoch): 414, 에러(err): 0.0203, 승리횟수(Win count): 212, 승리비율(Win ratio): 51.0843
# 반복(Epoch): 415, 에러(err): 0.0224, 승리횟수(Win count): 212, 승리비율(Win ratio): 50.9615
# 반복(Epoch): 416, 에러(err): 0.0143, 승리횟수(Win count): 213, 승리비율(Win ratio): 51.0791
# 반복(Epoch): 417, 에러(err): 0.0286, 승리횟수(Win count): 213, 승리비율(Win ratio): 50.9569
# 반복(Epoch): 418, 에러(err): 0.0107, 승리횟수(Win count): 214, 승리비율(Win ratio): 51.0740
# 반복(Epoch): 419, 에러(err): 0.0115, 승리횟수(Win count): 215, 승리비율(Win ratio): 51.1905
# 반복(Epoch): 420, 에러(err): 0.0158, 승리횟수(Win count): 216, 승리비율(Win ratio): 51.3064
# 반복(Epoch): 421, 에러(err): 0.0094, 승리횟수(Win count): 217, 승리비율(Win ratio): 51.4218
# 반복(Epoch): 422, 에러(err): 0.0109, 승리횟수(Win count): 218, 승리비율(Win ratio): 51.5366
# 반복(Epoch): 423, 에러(err): 0.0080, 승리횟수(Win count): 219, 승리비율(Win ratio): 51.6509
# 반복(Epoch): 424, 에러(err): 0.0118, 승리횟수(Win count): 220, 승리비율(Win ratio): 51.7647
# 반복(Epoch): 425, 에러(err): 0.0062, 승리횟수(Win count): 221, 승리비율(Win ratio): 51.8779
# 반복(Epoch): 426, 에러(err): 0.0078, 승리횟수(Win count): 222, 승리비율(Win ratio): 51.9906
# 반복(Epoch): 427, 에러(err): 0.0083, 승리횟수(Win count): 223, 승리비율(Win ratio): 52.1028
# 반복(Epoch): 428, 에러(err): 0.0086, 승리횟수(Win count): 224, 승리비율(Win ratio): 52.2145
# 반복(Epoch): 429, 에러(err): 0.0096, 승리횟수(Win count): 225, 승리비율(Win ratio): 52.3256
# 반복(Epoch): 430, 에러(err): 0.0041, 승리횟수(Win count): 226, 승리비율(Win ratio): 52.4362
# 반복(Epoch): 431, 에러(err): 0.0069, 승리횟수(Win count): 226, 승리비율(Win ratio): 52.3148
# 반복(Epoch): 432, 에러(err): 0.0518, 승리횟수(Win count): 227, 승리비율(Win ratio): 52.4249
# 반복(Epoch): 433, 에러(err): 0.0122, 승리횟수(Win count): 228, 승리비율(Win ratio): 52.5346
# 반복(Epoch): 434, 에러(err): 0.0137, 승리횟수(Win count): 229, 승리비율(Win ratio): 52.6437
# 반복(Epoch): 435, 에러(err): 0.0071, 승리횟수(Win count): 229, 승리비율(Win ratio): 52.5229
# 반복(Epoch): 436, 에러(err): 0.0712, 승리횟수(Win count): 230, 승리비율(Win ratio): 52.6316
# 반복(Epoch): 437, 에러(err): 0.1392, 승리횟수(Win count): 231, 승리비율(Win ratio): 52.7397
# 반복(Epoch): 438, 에러(err): 0.0329, 승리횟수(Win count): 232, 승리비율(Win ratio): 52.8474
# 반복(Epoch): 439, 에러(err): 0.1021, 승리횟수(Win count): 233, 승리비율(Win ratio): 52.9545
# 반복(Epoch): 440, 에러(err): 0.0136, 승리횟수(Win count): 234, 승리비율(Win ratio): 53.0612
# 반복(Epoch): 441, 에러(err): 0.0249, 승리횟수(Win count): 235, 승리비율(Win ratio): 53.1674
# 반복(Epoch): 442, 에러(err): 0.0173, 승리횟수(Win count): 236, 승리비율(Win ratio): 53.2731
# 반복(Epoch): 443, 에러(err): 0.0359, 승리횟수(Win count): 236, 승리비율(Win ratio): 53.1532
# 반복(Epoch): 444, 에러(err): 0.0256, 승리횟수(Win count): 237, 승리비율(Win ratio): 53.2584
# 반복(Epoch): 445, 에러(err): 0.0180, 승리횟수(Win count): 237, 승리비율(Win ratio): 53.1390
# 반복(Epoch): 446, 에러(err): 0.0282, 승리횟수(Win count): 238, 승리비율(Win ratio): 53.2438
# 반복(Epoch): 447, 에러(err): 0.0150, 승리횟수(Win count): 239, 승리비율(Win ratio): 53.3482
# 반복(Epoch): 448, 에러(err): 0.0265, 승리횟수(Win count): 240, 승리비율(Win ratio): 53.4521
# 반복(Epoch): 449, 에러(err): 0.0240, 승리횟수(Win count): 240, 승리비율(Win ratio): 53.3333
# 반복(Epoch): 450, 에러(err): 0.0119, 승리횟수(Win count): 241, 승리비율(Win ratio): 53.4368
# 반복(Epoch): 451, 에러(err): 0.0166, 승리횟수(Win count): 242, 승리비율(Win ratio): 53.5398
# 반복(Epoch): 452, 에러(err): 0.0199, 승리횟수(Win count): 243, 승리비율(Win ratio): 53.6424
# 반복(Epoch): 453, 에러(err): 0.0247, 승리횟수(Win count): 244, 승리비율(Win ratio): 53.7445
# 반복(Epoch): 454, 에러(err): 0.0301, 승리횟수(Win count): 245, 승리비율(Win ratio): 53.8462
# 반복(Epoch): 455, 에러(err): 0.0290, 승리횟수(Win count): 246, 승리비율(Win ratio): 53.9474
# 반복(Epoch): 456, 에러(err): 0.0278, 승리횟수(Win count): 247, 승리비율(Win ratio): 54.0481
# 반복(Epoch): 457, 에러(err): 0.0077, 승리횟수(Win count): 248, 승리비율(Win ratio): 54.1485
# 반복(Epoch): 458, 에러(err): 0.0157, 승리횟수(Win count): 249, 승리비율(Win ratio): 54.2484
# 반복(Epoch): 459, 에러(err): 0.0181, 승리횟수(Win count): 250, 승리비율(Win ratio): 54.3478
# 반복(Epoch): 460, 에러(err): 0.0846, 승리횟수(Win count): 251, 승리비율(Win ratio): 54.4469
# 반복(Epoch): 461, 에러(err): 0.0161, 승리횟수(Win count): 252, 승리비율(Win ratio): 54.5455
# 반복(Epoch): 462, 에러(err): 0.0134, 승리횟수(Win count): 253, 승리비율(Win ratio): 54.6436
# 반복(Epoch): 463, 에러(err): 0.0130, 승리횟수(Win count): 254, 승리비율(Win ratio): 54.7414
# 반복(Epoch): 464, 에러(err): 0.0118, 승리횟수(Win count): 255, 승리비율(Win ratio): 54.8387
# 반복(Epoch): 465, 에러(err): 0.0074, 승리횟수(Win count): 256, 승리비율(Win ratio): 54.9356
# 반복(Epoch): 466, 에러(err): 0.0097, 승리횟수(Win count): 257, 승리비율(Win ratio): 55.0321
# 반복(Epoch): 467, 에러(err): 0.0118, 승리횟수(Win count): 258, 승리비율(Win ratio): 55.1282
# 반복(Epoch): 468, 에러(err): 0.0208, 승리횟수(Win count): 258, 승리비율(Win ratio): 55.0107
# 반복(Epoch): 469, 에러(err): 0.0209, 승리횟수(Win count): 258, 승리비율(Win ratio): 54.8936
# 반복(Epoch): 470, 에러(err): 0.0248, 승리횟수(Win count): 259, 승리비율(Win ratio): 54.9894
# 반복(Epoch): 471, 에러(err): 0.0251, 승리횟수(Win count): 260, 승리비율(Win ratio): 55.0847
# 반복(Epoch): 472, 에러(err): 0.0855, 승리횟수(Win count): 260, 승리비율(Win ratio): 54.9683
# 반복(Epoch): 473, 에러(err): 0.0356, 승리횟수(Win count): 260, 승리비율(Win ratio): 54.8523
# 반복(Epoch): 474, 에러(err): 0.0582, 승리횟수(Win count): 260, 승리비율(Win ratio): 54.7368
# 반복(Epoch): 475, 에러(err): 0.0273, 승리횟수(Win count): 261, 승리비율(Win ratio): 54.8319
# 반복(Epoch): 476, 에러(err): 0.1169, 승리횟수(Win count): 262, 승리비율(Win ratio): 54.9266
# 반복(Epoch): 477, 에러(err): 0.0659, 승리횟수(Win count): 263, 승리비율(Win ratio): 55.0209
# 반복(Epoch): 478, 에러(err): 0.0364, 승리횟수(Win count): 264, 승리비율(Win ratio): 55.1148
# 반복(Epoch): 479, 에러(err): 0.0345, 승리횟수(Win count): 265, 승리비율(Win ratio): 55.2083
# 반복(Epoch): 480, 에러(err): 0.0289, 승리횟수(Win count): 265, 승리비율(Win ratio): 55.0936
# 반복(Epoch): 481, 에러(err): 0.0231, 승리횟수(Win count): 266, 승리비율(Win ratio): 55.1867
# 반복(Epoch): 482, 에러(err): 0.0330, 승리횟수(Win count): 267, 승리비율(Win ratio): 55.2795
# 반복(Epoch): 483, 에러(err): 0.0317, 승리횟수(Win count): 268, 승리비율(Win ratio): 55.3719
# 반복(Epoch): 484, 에러(err): 0.0434, 승리횟수(Win count): 269, 승리비율(Win ratio): 55.4639
# 반복(Epoch): 485, 에러(err): 0.0413, 승리횟수(Win count): 270, 승리비율(Win ratio): 55.5556
# 반복(Epoch): 486, 에러(err): 0.0678, 승리횟수(Win count): 271, 승리비율(Win ratio): 55.6468
# 반복(Epoch): 487, 에러(err): 0.0235, 승리횟수(Win count): 272, 승리비율(Win ratio): 55.7377
# 반복(Epoch): 488, 에러(err): 0.0451, 승리횟수(Win count): 273, 승리비율(Win ratio): 55.8282
# 반복(Epoch): 489, 에러(err): 0.0255, 승리횟수(Win count): 273, 승리비율(Win ratio): 55.7143
# 반복(Epoch): 490, 에러(err): 0.0192, 승리횟수(Win count): 273, 승리비율(Win ratio): 55.6008
# 반복(Epoch): 491, 에러(err): 0.0413, 승리횟수(Win count): 274, 승리비율(Win ratio): 55.6911
# 반복(Epoch): 492, 에러(err): 0.0532, 승리횟수(Win count): 275, 승리비율(Win ratio): 55.7809
# 반복(Epoch): 493, 에러(err): 0.0292, 승리횟수(Win count): 276, 승리비율(Win ratio): 55.8704
# 반복(Epoch): 494, 에러(err): 0.0170, 승리횟수(Win count): 277, 승리비율(Win ratio): 55.9596
# 반복(Epoch): 495, 에러(err): 0.0204, 승리횟수(Win count): 278, 승리비율(Win ratio): 56.0484
# 반복(Epoch): 496, 에러(err): 0.0229, 승리횟수(Win count): 279, 승리비율(Win ratio): 56.1368
# 반복(Epoch): 497, 에러(err): 0.0219, 승리횟수(Win count): 280, 승리비율(Win ratio): 56.2249
# 반복(Epoch): 498, 에러(err): 0.0088, 승리횟수(Win count): 281, 승리비율(Win ratio): 56.3126
# 반복(Epoch): 499, 에러(err): 0.0221, 승리횟수(Win count): 282, 승리비율(Win ratio): 56.4000
# 반복(Epoch): 500, 에러(err): 0.0286, 승리횟수(Win count): 282, 승리비율(Win ratio): 56.2874
# 트레이닝 완료
# /content/model.ckpt-500 경로에 파라미터가 저장되었습니다

# %%
from Chap_12_Reinforced_Learning_Training import CatchEnvironment, DQN
from IPython import display
import matplotlib.patches as patches
import pylab as pl
import time
import tensorflow as tf
import os

# %%
gridSize = 10
maxGames = 30
DQN_model = DQN()
env = CatchEnvironment(gridSize)
winCount = 0
loseCount = 0
numberOfGames = 0

# %%
def drawState(fruitRow, fruitColumn, basket, gridSize):
  fruitX = fruitColumn
  fruitY = (gridSize - fruitRow + 1)
  statusTitle = "Wins: " + str(winCount) + "  Losses: " + str(loseCount) + "  TotalGame: " + str(numberOfGames)
  axis.set_title(statusTitle, fontsize=30)
  for p in [
    # 배경의 위치를 지정합니다.
    patches.Rectangle(
        ((ground - 1), (ground)), 11, 10,
        facecolor="#000000"      # Black
    ),
    # 바구니의 위치를 지정합니다.
    patches.Rectangle(
        (basket - 1, ground), 2, 0.5,
        facecolor="#FF0000"     # Red
    ),
    # 과일의 위치를 지정합니다.
    patches.Rectangle(
        (fruitX - 0.5, fruitY - 0.5), 1, 1,
        facecolor="#0000FF"       # Blue
    ),   
    ]:
      axis.add_patch(p)
  display.clear_output(wait=True)
  display.display(pl.gcf())

# %%
# 저장된 파라미터를 불러옵니다.
ckpt = tf.train.Checkpoint(model=DQN_model)
latest_ckpt = tf.train.latest_checkpoint(os.getcwd())
#latest_ckpt = '/content/model.ckpt-201'

ckpt.restore(latest_ckpt)

print('저장된 파라미터를 불러왔습니다!')
# Out:
# 저장된 파라미터를 불러왔습니다!

# %%
# !pip install imageio

# !mkdir '/content/generated_output/'

import glob
import imageio
import matplotlib.pyplot as plt
import PIL

def display_image(epoch_no):
  return PIL.Image.open('/content/generated_output/image_at_epoch_{:04d}.png'.format(epoch_no))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.22.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (8.4.0)
# mkdir: cannot create directory ‘/content/generated_output/’: File exists

# %%
ground = 1
plot = pl.figure(figsize=(12,12))
axis = plot.add_subplot(111, aspect='equal')
axis.set_xlim([-1, 12])
axis.set_ylim([0, 12])

frame = 1

# maxGames 횟수만큼 게임을 플레이합니다.
while (numberOfGames < maxGames):
  numberOfGames = numberOfGames + 1

  # 최초의 상태를 정의합니다.
  isGameOver = False
  fruitRow, fruitColumn, basket = env.reset()
  currentState = env.observe()
  drawState(fruitRow, fruitColumn, basket, gridSize)

  while (isGameOver != True):
    # 현재 상태를 DQN의 입력값으로 넣고 구한 Q값중 가장 큰 Q값을 갖는 행동을 취합니다.
    q = DQN_model(currentState).numpy()
    action = q.argmax()

    # 행동을 취하고 다음 상태로 넘어갑니다.
    nextState, reward, gameOver, stateInfo = env.act(action)    
    fruitRow = stateInfo[0]
    fruitColumn = stateInfo[1]
    basket = stateInfo[2]
     
    # 과일을 받아내면 winCount를 1 늘리고 과일을 받아내지 못하면 loseCount를 1 늘립니다.
    if (reward == 1):
      winCount = winCount + 1
    elif (reward == -1):
      loseCount = loseCount + 1

    currentState = nextState
    isGameOver = gameOver
    drawState(fruitRow, fruitColumn, basket, gridSize)
    # 다음 행동을 취하기 전에 0.05초의 일시정지를 줍니다.
#    time.sleep(5)
    plt.savefig('/content/generated_output/image_at_frame_{:04d}.png'.format(frame))
    frame = frame+1

# 최종 출력결과 이미지를 하나로 정리합니다.
display.clear_output(wait=True)

# %%
anim_file = '/content/generated_output/dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('/content/generated_output/image*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):
      last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

import IPython
if IPython.version_info > (6,2,0,''):
  display.Image(filename=anim_file)

# %%
from google.colab import files

files.download(anim_file)
# !zip -r /content/file.zip /content/generated_output
files.download("/content/file.zip")
